# %%
from utils import data_analysis, data_handling
from ipywidgets import interact
import matplotlib.pyplot as plt

# %%
images = data_handling.load_images_from_directory('./data/images', '*.png')
print(images.shape)
# Out:
# (2624, 300, 300)

# %%
image = images[0]
mean = data_analysis.compute_mean(image)
print(mean)
median = data_analysis.compute_median(image)
print(median)
std = data_analysis.compute_std(image)
print(std)
max_value = data_analysis.compute_max(image)
print(max_value)
min_value = data_analysis.compute_min(image)
print(min_value)
mode = data_analysis.compute_mode(image)
print(mode[0])
# Out:
# 72.46966666666667
# 79.0
# 17.068925368113316
# 98
# 4
# 80

# %%
means = data_analysis.compute_means_from_images(images)
print(means)
medians = data_analysis.compute_median_from_images(images)
print(medians)
maxs = data_analysis.compute_max_from_images(images)
print(maxs)
mins = data_analysis.compute_min_from_images(images)
print(mins)
modes = data_analysis.compute_mode_from_images(images)
print(modes.transpose())
# Out:
# [ 72.46966667  84.83614444  76.5302     ... 155.1883     149.04152222
#  151.42333333]
# [ 79.  93.  83. ... 162. 156. 158.]
# [ 98 109  97 ... 215 202 204]
# [ 4  3  0 ... 43 40 41]
# [[ 80 100  88 ... 167 169 164]]

# %%
print(len(images))
image1 = images[0]
plt.imshow(image1)
plt.show()
# Out:
# 2624

# %%
image1 = data_analysis.average_images(images)
plt.imshow(image1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13040\2283736333.py in <module>
# ----> 1 image1 = data_analysis.average_images(images)
#       2 plt.imshow(image1)
#       3 plt.show()
#
# D:\research.informationsystem.elpv\utils\data_analysis.py in average_images(images)
#     104 def average_images(images):
#     105     avg_image = images[0]
# --> 106     for i in range(len(images)):
#     107         if i == 0:
#     108             pass
#
# TypeError: bad argument type for built-in operation
