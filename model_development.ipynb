# %%
import sys  
from utils import data_handling, model_development
import matplotlib.pyplot as plt
from ipywidgets import interact

# %% [markdown]
# # Configure the model training policy:

# %%
model_development.configure_settings()

# %% [markdown]
# # Load and preprocess data:

# %%
cell_images, cell_labels, cell_types = data_handling.load_data_from_file('./data/labels.csv')
X, Y = data_handling.preprocess_data(cell_images, cell_labels)

@interact(n = (0, cell_images.shape[0] - 1))
def display_data(n = 0):
    plt.imshow(cell_images[n], cmap = 'gray')
    print(f'Class: {cell_labels[n]}')
    print(f'Type: {cell_types[n]}')
    return None

@interact(n = (0, X.shape[0] - 1))
def display_data(n = 0):
    plt.imshow(X[n], cmap = 'gray')
    print(f'Class: {Y[n]}')
    print(f'Type: {cell_types[n]}')
    return None
# Out:
# interactive(children=(IntSlider(value=0, description='n', max=2623), Output()), _dom_classes=('widget-interact…
# interactive(children=(IntSlider(value=0, description='n', max=2623), Output()), _dom_classes=('widget-interact…

# %% [markdown]
# # Classification Model:

# %% [markdown]
# ## VGG19:

# %%
vgg19 = model_development.vgg19(input_shape = (300, 300, 3), model_name = 'VGG19', 
    visualize_model = False)
vgg19_history = model_development.train_model(vgg19, X, Y, 
'val_accuracy', ['accuracy', 'Precision', 'Recall'], 'binary_crossentropy', 
'adamax', 100, 16, '20220927', 'VGG19', (300, 300, 3))
# Out:
# c:\ProgramData\Anaconda3\envs\tensorflow_latest\lib\site-packages\keras\engine\data_adapter.py:1508: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   return t[start:end]
# Epoch 1/100
# 132/132 [==============================] - ETA: 0s - loss: 3.0967 - accuracy: 0.5650 - precision: 0.4531 - recall: 0.0644
# Epoch 1: val_accuracy improved from -inf to 0.59048, saving model to weights\20220927_VGG19_300x300x3.hdf5
# 132/132 [==============================] - 47s 305ms/step - loss: 3.0967 - accuracy: 0.5650 - precision: 0.4531 - recall: 0.0644 - val_loss: 0.6768 - val_accuracy: 0.5905 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/100
# ...
